# %% [markdown]
# <a href="https://colab.research.google.com/github/chw8207/math_basic/blob/main/%EB%8B%A4%EB%B3%80%EC%88%98%26%EB%B2%A1%ED%84%B0%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 일변수 벡터함수
#  $$r(t) = (f_1(t), f_2(t),···,f_n(t))^T$$

# %%
# 3차원 벡터함수 그래프 그리기
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d  # 3차원 그래프를 그리기 위한 툴킷
import matplotlib as mpl

mpl.style.use('bmh')         # 그래프에 사용할 테마 설정
mpl.style.use('seaborn-whitegrid')


plt.figure(figsize=(7,7))

ax = plt.axes(projection='3d')    # 3차원으로 투영되는 좌표 생성
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.zaxis.set_tick_params(labelsize=15)
ax.set_xlabel('$x$', fontsize=20)
ax.set_ylabel('$y$', fontsize=20)
ax.set_zlabel('$z$', fontsize=20)

# 입력값 t의 범위 설정
t = np.linspace(0,2,101)
X = np.sin(6*t)
y = 1/4*t
z = t**2/2

ax.plot3D(X,y,z,c='k')
ax.plot([X[0]], [y[0]], [z[0]], 'o', markersize=10, color='k',
        label=f't={t[0]:.2f}')
ax.plot([X[50]], [y[50]], [z[50]], '^', markersize=10, color='k',
        label=f't={t[50]:.2f}')
ax.plot([X[-1]], [y[-1]], [z[-1]], '*', markersize=10, color='k',
        label=f't={t[-1]:.2f}')

ax.legend(fontsize=15, loc='upper left')

plt.show()

# %% [markdown]
# ### 다변수 스칼라함수
# $$y = f(X)$$
# 예시 : $$f(x,y) = x+y$$

# %%
# 다변수 스칼라함수 그리기
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d  # 3차원 그래프를 그리기 위한 툴킷
import matplotlib as mpl

mpl.style.use('bmh')         # 그래프에 사용할 테마 설정
mpl.style.use('seaborn-whitegrid')

plt.figure(figsize=(7,7))

ax = plt.axes(projection='3d')
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.zaxis.set_tick_params(labelsize=15)
ax.set_xlabel(r'$x_1$', fontsize=20)
ax.set_ylabel(r'$x_2$', fontsize=20)
ax.set_zlabel(r'$z$', fontsize=20)

# 함수의 정의역 설정
X1 = np.linspace(-2,2,50)
X2 = np.linspace(-1,3,50)
X1, X2 = np.meshgrid(X1, X2)
Z = 50*(X2-X1**2)**2 + (2-X1)**2

# 계산된 값을 3차원 공간에 점으로 나타내기
ax.scatter3D(X1, X2, Z, marker='.', color='gray')

plt.show()
# Out:
# <ipython-input-1-912efdcbd50a>:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn-whitegrid')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d  # 3차원 그래프를 그리기 위한 툴킷
import matplotlib as mpl

mpl.style.use('bmh')         # 그래프에 사용할 테마 설정
mpl.style.use('seaborn-whitegrid')

plt.figure(figsize=(7,7))

ax = plt.axes(projection='3d')
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.zaxis.set_tick_params(labelsize=15)
ax.set_xlabel(r'$x_1$', fontsize=20)
ax.set_ylabel(r'$x_2$', fontsize=20)
ax.set_zlabel(r'$z$', fontsize=20)

# 함수의 정의역 설정
X1 = np.linspace(-2,2,50)
X2 = np.linspace(-1,3,50)
X1, X2 = np.meshgrid(X1, X2)
Z = 50*(X2-X1**2)**2 + (2-X1)**2

# 계산된 값을 3차원 공간에 점으로 나타내기
ax.plot_surface(X1, X2, Z, cmap=plt.cm.binary, edgecolor='k')

plt.show()
# Out:
# <ipython-input-3-590f2d311b6e>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn-whitegrid')

# %% [markdown]
# ### 다변수 벡터함수

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

fig = plt.figure(figsize=(7,7))
ax = plt.axes(projection='3d')
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.zaxis.set_tick_params(labelsize=15)
ax.set_xlabel(r'$x$', fontsize=20)
ax.set_ylabel(r'$y$', fontsize=20)
ax.set_zlabel(r'$z$', fontsize=20)

u = np.linspace(0,1,30)
v = np.linspace(0,1,30)
U,V = np.meshgrid(u,v)
X = U
Y = V
Z = (1+U**2)+(V/(1+V**2))

ax.scatter3D(X,Y,Z, marker='.', color='gray')

plt.show()

# %% [markdown]
# ### 합성함수
# $$y = f(x) = x^3 -15x +30$$
# $$z = g(y) = log(y)$$
# $$g\circ f(x) = log(x^3 -15x +30)$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.style.use('bmh')         # 그래프에 사용할 테마 설정
mpl.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(2,2)
fig.set_size_inches((16,13))

plt.subplots_adjust(wspace=0.2, hspace=0.2)
x = np.linspace(-4,4,100)
y = x**3 -15*x +30
z = np.log(y)

# 1사분면 그래프(f(x))
ax[0,0].plot(x, y, label = r'$x^3 -15x + 30$', color='k')
ax[0,0].xaxis.set_tick_params(labelsize=18)
ax[0,0].yaxis.set_tick_params(labelsize=18)
ax[0,0].set_xlabel('$x$', fontsize=25)
ax[0,0].set_ylabel('$y$', fontsize=25)
ax[0,0].legend(fontsize=18)
ax[0,0].grid(False)

# 2사분면 그래프(g(y))
ax[0,1].plot(y, z, label = r'$log(y)$', color='k')
ax[0,1].xaxis.set_tick_params(labelsize=18)
ax[0,1].yaxis.set_tick_params(labelsize=18)
ax[0,1].set_xlabel('$y$', fontsize=25)
ax[0,1].set_ylabel('$z$', fontsize=25)
ax[0,1].legend(fontsize=18)
ax[0,1].grid(False)

# 3사분면 그래프(g(f(x)))
ax[1,0].plot(x, z, '--', label = r'$log(f(x))$', color='k')
ax[1,0].xaxis.set_tick_params(labelsize=18)
ax[1,0].yaxis.set_tick_params(labelsize=18)
ax[1,0].set_xlabel('$x$', fontsize=25)
ax[1,0].set_ylabel('$z$', fontsize=25)
ax[1,0].legend(fontsize=18)
ax[1,0].grid(False)

# 4사분면 그래프(f(x)와 g(f(x))비교)
ax[1,1].plot(x, y, label = r'$x^3 -15x + 30$', color='k')
ax[1,1].xaxis.set_tick_params(labelsize=18)
ax[1,1].yaxis.set_tick_params(labelsize=18)
ax[1,1].set_xlabel('$x$', fontsize=25)
ax[1,1].set_ylabel('$y$', fontsize=25)
ax[1,1].legend(loc='lower left',fontsize=18)
ax[1,1].grid(False)

ax_ = ax[1,1].twinx()
ax_.plot(x, z, '--', label = r'$log(f(x))$', color='k')
ax_.yaxis.set_tick_params(labelsize=18)
ax_.set_ylabel('$z$', fontsize=25)
ax_.legend(fontsize=18)
ax_.grid(False)

plt.show()
# Out:
# <ipython-input-6-6b481257fcf8>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn-whitegrid')
